# %% [markdown]
# importance_type='gain'
# - 表示在森林模型生成中，累计降低了多少loss，（做了多少贡献）
# - 每次用这个点作为分裂，降级多少loss，然后累计
#
# 默认是split
# - 表示使用了多少次这个特征作为分裂点
# -

# %%
'split': lgbm_model.booster_.feature_importance(importance_type='split'),
# Out:
#   Cell In[1], line 1
#     'split': lgbm_model.booster_.feature_importance(importance_type='split'),
#     ^
# SyntaxError: illegal target for annotation
