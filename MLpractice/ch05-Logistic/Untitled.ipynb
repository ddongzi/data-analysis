# %% [markdown]
# ## 5.1 Logistic回归和Sigmod函数
# - 二分类策略
#
# 问题：如何将数据特征转换为sigmod函数输入？
#
# => 最佳回归系数w. 通过w与特征值的线性积，得到输入。

# %% [markdown]
# ## 5.2 Logistic最佳回归系数:梯度上升。
# $z=w_{0} x_{0}+w_{1} x_{1}+w_{2} x_{2}+\cdots+w_{n} x_{n}$
# ![image.png](attachment:9c823ba6-61d6-4120-a95e-7c89e2153b50.png)
